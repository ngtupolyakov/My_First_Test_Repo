# %% [markdown]
# <a href="https://colab.research.google.com/github/ngtupolyakov/My_First_Test_Repo/blob/main/Markdown.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Пример использования Markdown
#
#   Нужно сделать:
#
#   1.   Список
#   2.   Рисунок
#   3.   Таблицу
#   4.   Ссылку
#
# ![изображение_2026-03-29_143256453.png](data:image/png;base64,...)
#
# | № | I | U |
# |-----------|-----------|-----------|
# | 1 | 10А  | 220В |
# | 2    | 5А  | 110В |
#
# [Ссылка](https://www.youtube.com/watch?v=HIcSWuKMwOw)
